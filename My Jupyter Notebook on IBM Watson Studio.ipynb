# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Sergio Mendieta**<br>
# Data Scientist

# %% [markdown]
# *Data Science is fascinating, I work a lot with data from surveys about customer satisfaction, my job is to find valuable insights from that data in order to take the best decisions on what direction to guide my team to ensure success; being able to use Data Science tools to get even better and more accurate insights to guarantee my decisions are the right one is just priceless*

# %% [markdown]
# ### My code allows you to add 2 numbers and display the result

# %%
a = int(input("Enter the first number to be added (not negative numbers allowed): "))
b = int(input("Enter the second number to be added (not negative numbers allowed): "))
c = a + b
print("Your result is: ", c)

# %% [markdown]
# **Instructions to use the program**
# <ol>
# <li>Input first number and hit enter</li>
# <li>Input second number and hit enter</li>
# <li>Confirm your answer</li>
# </ol>
#
# **You can see an image of a calculator below**<br>
# ![Calculator-Transparent-Background.png](attachment:Calculator-Transparent-Background.png)
#
# **Or can go to the website where it was taken from**<br>
# <a href=https://www.pngmart.com/image/95244/png/95243 target="_blank">Calculator Transparent Background</a>
